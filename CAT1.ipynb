# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns

# %%
URL ='https://www.worldometers.info/population/countries-in-africa-by-population/'

# %%
df = pd.read_html(URL)[0]

# %%
df.head()
# Out:
#    # Country (or dependency)  Population  (2024) Yearly  Change  Net  Change  \
# 0  1                 Nigeria           232679478         2.10 %      4796533
# 1  2                Ethiopia           132059767         2.62 %      3368075
# 2  3                   Egypt           116538258         1.75 %      2002486
# 3  4                DR Congo           109276265         3.30 %      3486534
# 4  5                Tanzania            68560157         2.92 %      1942551
#
#    Density  (P/Km²)  Land Area  (Km²)  Migrants  (net)  Fert.  Rate  \
# 0               255            910770           -35202          4.4
# 1               132           1000000            30069          3.9
# 2               117            995450           123884          2.7
# 3                48           2267050           -26968          6.0
# 4                77            885800           -29865          4.5
#
#    Med.  Age Urban  Pop % World  Share
# 0         18         54 %       2.85 %
# ...

# %%
df
# Out:
#      #   Country (or dependency)  Population  (2024) Yearly  Change  \
# 0    1                   Nigeria           232679478         2.10 %
# 1    2                  Ethiopia           132059767         2.62 %
# 2    3                     Egypt           116538258         1.75 %
# 3    4                  DR Congo           109276265         3.30 %
# 4    5                  Tanzania            68560157         2.92 %
# 5    6              South Africa            64007187         1.26 %
# 6    7                     Kenya            56432944         1.98 %
# 7    8                     Sudan            50448963         0.81 %
# 8    9                    Uganda            50015092         2.79 %
# 9   10                   Algeria            46814308         1.41 %
# 10  11                   Morocco            38081173         0.98 %
# 11  12                    Angola            37885849         3.09 %
# 12  13                Mozambique            34631766         2.96 %
# ...

# %%
df2 = df.drop(columns=['#'])
df2.head()
# Out:
#   Country (or dependency)  Population  (2024) Yearly  Change  Net  Change  \
# 0                 Nigeria           232679478         2.10 %      4796533
# 1                Ethiopia           132059767         2.62 %      3368075
# 2                   Egypt           116538258         1.75 %      2002486
# 3                DR Congo           109276265         3.30 %      3486534
# 4                Tanzania            68560157         2.92 %      1942551
#
#    Density  (P/Km²)  Land Area  (Km²)  Migrants  (net)  Fert.  Rate  \
# 0               255            910770           -35202          4.4
# 1               132           1000000            30069          3.9
# 2               117            995450           123884          2.7
# 3                48           2267050           -26968          6.0
# 4                77            885800           -29865          4.5
#
#    Med.  Age Urban  Pop % World  Share
# 0         18         54 %       2.85 %
# ...

# %%
df2.describe()
# Out:
#        Population  (2024)   Net  Change  Density  (P/Km²)  Land Area  (Km²)  \
# count        5.800000e+01  5.800000e+01         58.000000      5.800000e+01
# mean         2.612312e+07  5.925918e+05        131.689655      5.111807e+05
# std          3.987530e+07  9.126682e+05        175.534093      5.848486e+05
# min          5.237000e+03 -2.419000e+03          2.000000      3.750000e+02
# 25%          2.525592e+06  4.955050e+04         29.000000      2.868000e+04
# 50%          1.415218e+07  3.257065e+05         69.500000      2.698000e+05
# 75%          3.195727e+07  7.406598e+05        131.500000      8.140625e+05
# max          2.326795e+08  4.796533e+06        871.000000      2.381740e+06
#
#        Migrants  (net)  Fert.  Rate  Med.  Age
# count        58.000000    58.000000  58.000000
# mean     -11108.120690     3.713793  21.413793
# std       84518.921666     1.172559   6.808237
# min     -544257.000000     1.200000  14.000000
# ...

# %%
df3 = df2.select_dtypes(include=np.number)
df3.head()
# Out:
#    Population  (2024)  Net  Change  Density  (P/Km²)  Land Area  (Km²)  \
# 0           232679478      4796533               255            910770
# 1           132059767      3368075               132           1000000
# 2           116538258      2002486               117            995450
# 3           109276265      3486534                48           2267050
# 4            68560157      1942551                77            885800
#
#    Migrants  (net)  Fert.  Rate  Med.  Age
# 0           -35202          4.4         18
# 1            30069          3.9         19
# 2           123884          2.7         24
# 3           -26968          6.0         16
# 4           -29865          4.5         17

# %%
df3.corr()
# Out:
#                     Population  (2024)  Net  Change  Density  (P/Km²)  \
# Population  (2024)            1.000000     0.956441         -0.045547
# Net  Change                   0.956441     1.000000         -0.058994
# Density  (P/Km²)             -0.045547    -0.058994          1.000000
# Land Area  (Km²)              0.479951     0.490796         -0.408421
# Migrants  (net)              -0.034859     0.038571          0.005495
# Fert.  Rate                   0.192832     0.341173         -0.101266
# Med.  Age                    -0.181702    -0.271655          0.079323
#
#                     Land Area  (Km²)  Migrants  (net)  Fert.  Rate  Med.  Age
# Population  (2024)          0.479951        -0.034859     0.192832  -0.181702
# Net  Change                 0.490796         0.038571     0.341173  -0.271655
# Density  (P/Km²)           -0.408421         0.005495    -0.101266   0.079323
# Land Area  (Km²)            1.000000        -0.138140     0.319144  -0.191330
# ...

# %%
df3.columns
# Out:
# Index(['Population  (2024)', 'Net  Change', 'Density  (P/Km²)',
#        'Land Area  (Km²)', 'Migrants  (net)', 'Fert.  Rate', 'Med.  Age'],
#       dtype='object')

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()
lm
# Out:
# LinearRegression()

# %%
X = df3[['Net  Change']]
Y = df3['Population  (2024)']

# %%
lm.fit(X,Y)
# Out:
# LinearRegression()

# %%
Yhat=lm.predict(X)
Yhat[0:5]
# Out:
# array([2.01796422e+08, 1.42104355e+08, 8.50394437e+07, 1.47054492e+08,
#        8.25348941e+07])

# %%
import seaborn as sns
width = 12
height = 10
plt.figure(figsize=(width, height))


ax1 = sns.distplot(df3['Population  (2024)'], hist=False, color="r", label="Actual Value")
sns.distplot(Yhat, hist=False, color="b", label="Fitted Values" , ax=ax1)


plt.title('Population (2024) Vs Net Change')
plt.xlabel('Net  Change')
plt.ylabel('Population  (2024)')

plt.show()
plt.close()
# Out:
# <ipython-input-56-63d318dbce5f>:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1 = sns.distplot(df3['Population  (2024)'], hist=False, color="r", label="Actual Value")
# <ipython-input-56-63d318dbce5f>:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score


df3.columns = df3.columns.str.strip()

X = df3[['Net  Change']]
Y = df3['Population  (2024)']


X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)


model = LinearRegression()


model.fit(X_train, Y_train)


Y_pred = model.predict(X_test)


r2 = r2_score(Y_test, Y_pred)
mse = mean_squared_error(Y_test, Y_pred)


print(f'R-squared: {r2}')
print(f'Mean Squared Error: {mse}')
# Out:
# R-squared: 0.9308428538409982
# Mean Squared Error: 295193903127481.44

# %% [markdown]
# MULTIPLE LINEAR CORELATION

# %%
Z = df3[['Population  (2024)', 'Density  (P/Km²)','Migrants  (net)','Fert.  Rate', 'Med.  Age']]

# %%
lm.fit(Z, df3['Net  Change'])
# Out:
# LinearRegression()

# %%
lm.intercept_
# Out:
# np.float64(-856643.1904082354)

# %%
lm.coef_
# Out:
# array([2.12577331e-02, 7.39841158e-01, 8.53628744e-01, 1.81455497e+05,
#        1.07133450e+04])

# %%
x = Z
y = np.array(df3['Net  Change'])

# %%
lm.intercept_
# Out:
# np.float64(-856643.1904082354)

# %%
import seaborn as sns
width = 12
height = 10
plt.figure(figsize=(width, height))


ax1 = sns.distplot(Z, hist=False, color="r", label="Actual Value")
sns.distplot(Yhat, hist=False, color="b", label="Fitted Values" , ax=ax1)


plt.title('Z Vs Net Change')
plt.xlabel('Z')
plt.ylabel('Net  Change')

plt.show()
plt.close()
# Out:
# <ipython-input-71-36c178294b23>:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1 = sns.distplot(Z, hist=False, color="r", label="Actual Value")
# <ipython-input-71-36c178294b23>:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score


df3.columns = df3.columns.str.strip()

X = Z
Y = df3['Net  Change']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

model = LinearRegression()

model.fit(X_train, Y_train)

Y_pred = model.predict(X_test)

r2 = r2_score(Y_test, Y_pred)
mse = mean_squared_error(Y_test, Y_pred)


print(f'R-squared: {r2}')
print(f'Mean Squared Error: {mse}')
# Out:
# R-squared: 0.9490880488529487
# Mean Squared Error: 112762107730.8567

# %%
def PlotPolly(model, independent_variable, dependent_variabble, Name):
    x_new = np.linspace(15, 55, 100)
    y_new = model(x_new)

    plt.plot(independent_variable, dependent_variabble, '.', x_new, y_new, '-')
    plt.title('Polynomial Fit with Matplotlib for Price ~ Length')
    ax = plt.gca()
    ax.set_facecolor((0.898, 0.898, 0.898))
    fig = plt.gcf()
    plt.xlabel('Med.  Age')
    plt.ylabel('Fert.  Rate')

    plt.show()
    plt.close()

# %%
import seaborn as sns
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.regplot(x="Med.  Age", y="Fert.  Rate", data=df3)
plt.ylim(0,)
# Out:
# (0.0, 6.437849983339229)

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score


df3.columns = df3.columns.str.strip()

X = df3[['Med.  Age',]]
Y = df3['Fert.  Rate']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

model = LinearRegression()

model.fit(X_train, Y_train)

Y_pred = model.predict(X_test)

r2 = r2_score(Y_test, Y_pred)
mse = mean_squared_error(Y_test, Y_pred)


print(f'R-squared: {r2}')
print(f'Mean Squared Error: {mse}')
# Out:
# R-squared: 0.6336970699636759
# Mean Squared Error: 0.6364259032346383
